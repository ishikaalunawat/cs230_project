# %%
import torchvision
from torchview import draw_graph
from models_denoising import DenoisingCNN, DenoisingUNet, ResidualUNet, MotionAwareDenoiser

# %%
denoisingCNN = DenoisingCNN()
denoising_unet = DenoisingUNet()
residual_unet = ResidualUNet()
motionaware = MotionAwareDenoiser()

# %%
model_graph = draw_graph(denoisingCNN, input_size=(1,3,224, 224), expand_nested=False)
model_graph.visual_graph

# %%
model_graph = draw_graph(denoising_unet, input_size=(1,3,224, 224), expand_nested=False)
model_graph.visual_graph

# %%
model_graph = draw_graph(residual_unet, input_size=(1,3,224, 224), expand_nested=False)
model_graph.visual_graph

# %%
model_graph = draw_graph(motionaware, input_size=(1,3,224, 224), expand_nested=False)
model_graph.visual_graph
